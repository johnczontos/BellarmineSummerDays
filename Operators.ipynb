# %% [markdown]
# <a href="https://colab.research.google.com/github/johnczontos/BellarmineSummerDays/blob/Operators/Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Arithmatic operators

# %%
x = 15
y = 4

# %%
# addition
print('x + y =',x + y)
# Out:
# x + y = 19

# %%
# subtraction
print('x - y =',x - y)
# Out:
# x - y = 11

# %%
# multiplication
print('x * y =',x*y)
# Out:
# x * y = 60

# %%
# division
print('x / y =',x/y)
# Out:
# x / y = 3.75

# %%
# floor/integer division
print('x // y =', x//y)
# Out:
# x // y = 3

# %%
# exponent
print('x ** y =',x**y)
# Out:
# x ** y = 50625

# %% [markdown]
# ## Comparison operators

# %%
x = 12
y = 12

# %%
# Greater than
print('x > y is', x>y)
# Out:
# x > y is False

# %%
# Less than
print('x < y is',x<y)
# Out:
# x < y is False

# %%
# Equal to
print('x == y is',x==y)
# Out:
# x == y is False

# %%
# not equal to
print('x != y is',x!=y)
# Out:
# x != y is True

# %%
# Greater than or equal to
print('x >= y is',x>=y)
# Out:
# x >= y is True

# %%
# Less than or equal to
print('x <= y is',x<=y)
# Out:
# x <= y is True

# %% [markdown]
# ## Logical Operators

# %%
x = False
y = False

# %%
# and
print('x and y is', x and y)
# Out:
# x and y is False

# %% [markdown]
# ![Screen Shot 2021-06-18 at 4.56.47 AM.png](data:image/png;base64,...)

# %%
# or
print('x or y is', x or y)
# Out:
# x or y is False

# %% [markdown]
# ![Screen Shot 2021-06-18 at 4.56.53 AM.png](data:image/png;base64,...)

# %%
# not
print('not x is',not x)
# Out:
# not x is True

# %% [markdown]
# ![Screen Shot 2021-06-18 at 4.56.59 AM.png](data:image/png;base64,...)

# %% [markdown]
# ## Assignment operators

# %%
# x = 5
# set x to equal 5
x = 5
print(x)
# Out:
# 5

# %%
# x = x + 5
x += 5
print(x)
# Out:
# 10

# %%
# x = x - 5
x -= 5
print(x)
# Out:
# 5

# %%
# x = x * 5
x *= 5

# %%
# x = x / 5
x /= 5

# %%
# x = x // 5
x //= 5

# %% [markdown]
# ## Bonus operators

# %%
# Identity operators
# is: True if the operands are identical 
#           (refer to the same object in memory)
# is not: True if the operands are not identical 
#           (do not refer to the same object in memory)

x1 = 5
y1 = 5
x2 = 'Hello'
y2 = 'Hello'
x3 = [1,2,3]
y3 = [1,2,3]

# Output: False
print(x1 is not y1)

# Output: True
print(x2 is y2)

# Output: False
print(x3 is y3)

# %%
# Membership operators
# in:   True if value/variable is found in the sequence
# not in:	True if value/variable is not found in the sequence

x = 'Hello world'
y = [1, 2, 3]

# Output: True
print('Hello' in x)

# Output: True
print('hello' in x)

# Output: True
print(1 in y)

# Output: False
print('a' in y)
# Out:
# True
# False
# True
# False
